# %% [markdown]
# <a href="https://colab.research.google.com/github/SabadModi/MaskAndSocialDistancingDetection/blob/main/Mask_and_Social_Distancing_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SabadModi/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 228 (delta 30), reused 224 (delta 26), pack-reused 0
# Receiving objects: 100% (228/228), 153.45 MiB | 29.81 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# Checking out files: 100% (209/209), done.

# %%
# %cd yolov5/yolov5-SocialDistancing/
# Out:
# /content/yolov5/yolov5-SocialDistancing

# %%
# !pip install -U -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-fcuwdsan
#   Running command git clone -q https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-fcuwdsan
# ...
#      |████████████████████████████████| 2.0 MB 8.7 MB/s
# ...
#      |████████████████████████████████| 20.3 MB 56.1 MB/s
# ...
#      |████████████████████████████████| 49.9 MB 14 kB/s
# ...
#      |████████████████████████████████| 10.3 MB 34.0 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 36.9 MB/s
# ...
#      |████████████████████████████████| 636 kB 44.8 MB/s
# ...
#      |████████████████████████████████| 28.5 MB 45 kB/s
# ...
#      |████████████████████████████████| 76 kB 3.9 MB/s
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=263912 sha256=e095a32b925859d837306d82ea40e9296491e999e0552951ff7869d0e7e33a6a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z3213tq_/wheels/e2/6b/1d/344ac773c7495ea0b85eb228bc66daec7400a143a92d36b7b1
# Successfully built pycocotools
# ...

# %%
# %cd yolov5/yolov5-SocialDistancing/
# Out:
# /content/yolov5/yolov5-SocialDistancing

# %%
import PIL

# %%
# !python detect.py --source ./inference/videos/img.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', fourcc='mp4v', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='./inference/videos/img.jpg', view_img=False, weights='weights/yolov5s.pt')
# Using CPU
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:671: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:671: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
# ...

# %%
PIL.Image.open("inference/output/img.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x577 at 0x7F811995D110>

# %%
# %cd ../../
# %ls
# Out:
# /content
# sample_data/  yolov5/

# %%
# %cd yolov5/yolov5/
# Out:
# /content/yolov5/yolov5

# %%
# !pip install -U -r requirements.txt  # install dependencies
# Out:
# ...
#      |████████████████████████████████| 15.7 MB 73 kB/s
# ...
#      |████████████████████████████████| 11.5 MB 220 kB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.17.0
#     Uninstalling numpy-1.17.0:
#       Successfully uninstalled numpy-1.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.5.0 requires numpy~=1.19.2, but you have numpy 1.21.1 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import torch
from IPython.display import Image  # for displaying images

# %%
# %cd ../../
# %ls
# Out:
# /content
# sample_data/  yolov5/

# %%
# !git clone https://github.com/iAmEthanMai/mask-detection-dataset.git
# Out:
# Cloning into 'mask-detection-dataset'...
# remote: Enumerating objects: 3502, done.
# remote: Counting objects: 100% (913/913), done.
# remote: Compressing objects: 100% (868/868), done.
# remote: Total 3502 (delta 24), reused 861 (delta 2), pack-reused 2589
# Receiving objects: 100% (3502/3502), 400.65 MiB | 22.40 MiB/s, done.
# Resolving deltas: 100% (879/879), done.
# Checking out files: 100% (2567/2567), done.

# %%
# %cd yolov5/yolov5/
# Out:
# /content/yolov5/yolov5

# %%
import PIL

# %%
# !python3 detect.py --source /content/yolov5/yolov5-SocialDistancing/inference/output/img.jpg --weights /content/yolov5/yolov5/runs/train/exp3/weights/last.pt
# Out:
# detect: weights=['/content/yolov5/yolov5/runs/train/exp3/weights/last.pt'], source=/content/yolov5/yolov5-SocialDistancing/inference/output/img.jpg, imgsz=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 848c635 torch 1.9.0+cu102 CPU
#
# Fusing layers...
# Model Summary: 224 layers, 7059304 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /content/yolov5/yolov5-SocialDistancing/inference/output/img.jpg: 384x640 1 0, 5 1s, Done. (0.294s)
# Results saved to runs/detect/exp9
# Done. (0.339s)

# %%
PIL.Image.open("runs/detect/exp9/img.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x577 at 0x7FCC511E8390>
